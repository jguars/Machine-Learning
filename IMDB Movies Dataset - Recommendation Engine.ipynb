# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 15.9 MB/s eta 0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.1
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('punkt_tab')
pd.set_option('display.max_columns', None)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
df = pd.read_csv('IMDB_Top250Engmovies2_OMDB_Detailed.csv')
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1           2             The Godfather  1972         R  24 Mar 1972  175 min
# 2           3    The Godfather: Part II  1974         R  20 Dec 1974  202 min
# 3           4           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 4           5              12 Angry Men  1957  APPROVED  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3  1,825,626  tt0111161  movie
# 1        9.2/10      100.0         9.2  1,243,444  tt0068646  movie
# 2        9.0/10       85.0         9.0    856,870  tt0071562  movie
# 3        9.0/10       82.0         9.0  1,802,351  tt0468569  movie
# 4        8.9/10       96.0         8.9    494,215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website  Response
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True

# %%
len(df)
# Out:
# 250

# %%
df['Plot'][0]
# Out:
# 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'

# %% [markdown]
# # Data Preprocessing

# %%
df['clean_plot'] = df['Plot'].str.lower()
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('\s+', ' ', x))
df['clean_plot']
# Out:
# 0      two imprisoned men bond over a number of years...
# 1      the aging patriarch of an organized crime dyna...
# 2      the early life and career of vito corleone in ...
# 3      when the menace known as the joker emerges fro...
# 4      a jury holdout attempts to prevent a miscarria...
#                              ...
# 245    the desperate life of a chronic alcoholic is f...
# 246    a something supervising staff member of a resi...
# 247    a newspaper editor uses every trick in the boo...
# 248    an old man makes a long journey by lawn mover ...
# 249    a mumbai teen reflects on his upbringing in th...
# Name: clean_plot, Length: 250, dtype: object

# %%
df['clean_plot'] = df['clean_plot'].apply(lambda x: nltk.word_tokenize(x))
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, over, a, number, ...
# 1      [the, aging, patriarch, of, an, organized, cri...
# 2      [the, early, life, and, career, of, vito, corl...
# 3      [when, the, menace, known, as, the, joker, eme...
# 4      [a, jury, holdout, attempts, to, prevent, a, m...
#                              ...
# 245    [the, desperate, life, of, a, chronic, alcohol...
# 246    [a, something, supervising, staff, member, of,...
# 247    [a, newspaper, editor, uses, every, trick, in,...
# 248    [an, old, man, makes, a, long, journey, by, la...
# 249    [a, mumbai, teen, reflects, on, his, upbringin...
# Name: clean_plot, Length: 250, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = nltk.corpus.stopwords.words('english')
plot = []
for sentence in df['clean_plot']:
    temp = []
    for word in sentence:
        if word not in stop_words and len(word) >= 3:
            temp.append(word)
    plot.append(temp)
plot
# Out:
# [['two',
#   'imprisoned',
#   'men',
#   'bond',
#   'number',
#   'years',
#   'finding',
#   'solace',
#   'eventual',
#   'redemption',
#   'acts',
#   'common',
#   'decency'],
#  ['aging',
#   'patriarch',
#   'organized',
#   'crime',
#   'dynasty',
#   'transfers',
#   'control',
#   'clandestine',
#   'empire',
#   'reluctant',
#   'son'],
#  ['early',
#   'life',
#   'career',
#   'vito',
#   'corleone',
#   'new',
#   'york',
#   'portrayed',
#   'son',
#   'michael',
#   'expands',
#   'tightens',
#   'grip',
#   'family',
#   'crime',
#   'syndicate'],
#  ['menace',
#   'known',
#   'joker',
#   'emerges',
#   'mysterious',
#   'past',
#   'wreaks',
#   'havoc',
#   'chaos',
#   'people',
#   'gotham',
#   'dark',
#   'knight',
#   'must',
#   'accept',
#   'one',
#   'greatest',
#   'psychological',
#   'physical',
#   'tests',
#   'ability',
#   'fight',
#   'injustice'],
#  ['jury',
#   'holdout',
#   'attempts',
#   'prevent',
#   'miscarriage',
#   'justice',
#   'forcing',
#   'colleagues',
#   'reconsider',
#   'evidence'],
#  ['german',
#   'occupied',
#   'poland',
#   'world',
#   'war',
#   'oskar',
#   'schindler',
#   'gradually',
#   'becomes',
#   'concerned',
#   'jewish',
#   'workforce',
#   'witnessing',
#   'persecution',
#   'nazi',
#   'germans'],
#  ['gandalf',
#   'aragorn',
#   'lead',
#   'world',
#   'men',
#   'sauron',
#   'army',
#   'draw',
#   'gaze',
#   'frodo',
#   'sam',
#   'approach',
#   'mount',
#   'doom',
#   'one',
#   'ring'],
#  ['lives',
#   'two',
#   'mob',
#   'hit',
#   'men',
#   'boxer',
#   'gangster',
#   'wife',
#   'pair',
#   'diner',
#   'bandits',
#   'intertwine',
#   'four',
#   'tales',
#   'violence',
#   'redemption'],
#  ['insomniac',
#   'office',
#   'worker',
#   'looking',
#   'way',
#   'change',
#   'life',
#   'crosses',
#   'paths',
#   'devil',
#   'may',
#   'care',
#   'soap',
#   'maker',
#   'forming',
#   'underground',
#   'fight',
#   'club',
#   'evolves',
#   'something',
#   'much',
#   'much'],
#  ['meek',
#   'hobbit',
#   'shire',
#   'eight',
#   'companions',
#   'set',
#   'journey',
#   'destroy',
#   'powerful',
#   'one',
#   'ring',
#   'save',
#   'middle',
#   'earth',
#   'dark',
#   'lord',
#   'sauron'],
#  ['intelligent',
#   'forrest',
#   'gump',
#   'accidentally',
#   'present',
#   'many',
#   'historic',
#   'moments',
#   'true',
#   'love',
#   'jenny',
#   'curran',
#   'eludes'],
#  ['rebels',
#   'overpowered',
#   'empire',
#   'newly',
#   'established',
#   'base',
#   'luke',
#   'skywalker',
#   'begins',
#   'jedi',
#   'training',
#   'master',
#   'yoda',
#   'friends',
#   'accept',
#   'shelter',
#   'questionable',
#   'ally',
#   'darth',
#   'vader',
#   'hunts',
#   'plan',
#   'capture',
#   'luke'],
#  ['thief',
#   'steals',
#   'corporate',
#   'secrets',
#   'use',
#   'dream',
#   'sharing',
#   'technology',
#   'given',
#   'inverse',
#   'task',
#   'planting',
#   'idea',
#   'mind',
#   'ceo'],
#  ['frodo',
#   'sam',
#   'edge',
#   'closer',
#   'mordor',
#   'help',
#   'shifty',
#   'gollum',
#   'divided',
#   'fellowship',
#   'makes',
#   'stand',
#   'sauron',
#   'new',
#   'ally',
#   'saruman',
#   'hordes',
#   'isengard'],
#  ['criminal',
#   'pleads',
#   'insanity',
#   'getting',
#   'trouble',
#   'mental',
#   'institution',
#   'rebels',
#   'oppressive',
#   'nurse',
#   'rallies',
#   'scared',
#   'patients'],
#  ['story',
#   'henry',
#   'hill',
#   'life',
#   'teen',
#   'years',
#   'years',
#   'mafia',
#   'covering',
#   'relationship',
#   'wife',
#   'karen',
#   'hill',
#   'mob',
#   'partners',
#   'jimmy',
#   'conway',
#   'tommy',
#   'devitto',
#   'italian',
#   'american',
#   'crime',
#   'syndicate'],
#  ['computer',
#   'hacker',
#   'learns',
#   'mysterious',
#   'rebels',
#   'true',
#   'nature',
#   'reality',
#   'role',
#   'war',
#   'controllers'],
#  ['luke',
#   'skywalker',
#   'joins',
#   'forces',
#   'jedi',
#   'knight',
#   'cocky',
#   'pilot',
#   'wookiee',
#   'two',
#   'droids',
#   'save',
#   'galaxy',
#   'empire',
#   'world',
#   'destroying',
#   'battle',
#   'station',
#   'also',
#   'attempting',
#   'rescue',
#   'princess',
#   'leia',
#   'evil',
#   'darth',
#   'vader'],
#  ['two',
#   'detectives',
#   'rookie',
#   'veteran',
#   'hunt',
#   'serial',
#   'killer',
#   'uses',
#   'seven',
#   'deadly',
#   'sins',
#   'motives'],
#  ['angel',
#   'sent',
#   'heaven',
#   'help',
#   'desperately',
#   'frustrated',
#   'businessman',
#   'showing',
#   'life',
#   'would',
#   'like',
#   'never',
#   'existed'],
#  ['young',
#   'cadet',
#   'must',
#   'confide',
#   'incarcerated',
#   'manipulative',
#   'killer',
#   'receive',
#   'help',
#   'catching',
#   'another',
#   'serial',
#   'killer',
#   'skins',
#   'victims'],
#  ['sole',
#   'survivor',
#   'tells',
#   'twisty',
#   'events',
#   'leading',
#   'horrific',
#   'gun',
#   'battle',
#   'boat',
#   'began',
#   'five',
#   'criminals',
#   'met',
#   'seemingly',
#   'random',
#   'police',
#   'lineup'],
#  ['mathilda',
#   'year',
#   'old',
#   'girl',
#   'reluctantly',
#   'taken',
#   'professional',
#   'assassin',
#   'family',
#   'murdered',
#   'mathilda',
#   'form',
#   'unusual',
#   'relationship',
#   'becomes',
#   'prot',
#   'learns',
#   'assassin',
#   'trade'],
#  ['following',
#   'normandy',
#   'landings',
#   'group',
#   'soldiers',
#   'behind',
#   'enemy',
#   'lines',
#   'retrieve',
#   'paratrooper',
#   'whose',
#   'brothers',
#   'killed',
#   'action'],
#  ['aid',
#   'wealthy',
#   'erratic',
#   'tippler',
#   'dewy',
#   'eyed',
#   'tramp',
#   'fallen',
#   'love',
#   'sightless',
#   'flower',
#   'girl',
#   'accumulates',
#   'money',
#   'able',
#   'help',
#   'medically'],
#  ['team',
#   'explorers',
#   'travel',
#   'wormhole',
#   'space',
#   'attempt',
#   'ensure',
#   'humanity',
#   'survival'],
#  ['former',
#   'neo',
#   'nazi',
#   'skinhead',
#   'tries',
#   'prevent',
#   'younger',
#   'brother',
#   'going',
#   'wrong',
#   'path'],
#  ['tramp',
#   'struggles',
#   'live',
#   'modern',
#   'industrial',
#   'society',
#   'help',
#   'young',
#   'homeless',
#   'woman'],
#  ['casablanca',
#   'december',
#   'cynical',
#   'american',
#   'expatriate',
#   'encounters',
#   'former',
#   'lover',
#   'unforeseen',
#   'complications'],
#  ['lives',
#   'guards',
#   'death',
#   'row',
#   'affected',
#   'one',
#   'charges',
#   'black',
#   'man',
#   'accused',
#   'child',
#   'murder',
#   'rape',
#   'yet',
#   'mysterious',
#   'gift'],
#  ['phoenix',
#   'secretary',
#   'embezzles',
#   'employer',
#   'client',
#   'goes',
#   'run',
#   'checks',
#   'remote',
#   'motel',
#   'run',
#   'young',
#   'man',
#   'domination',
#   'mother'],
#  ['archaeologist',
#   'adventurer',
#   'indiana',
#   'jones',
#   'hired',
#   'government',
#   'find',
#   'ark',
#   'covenant',
#   'nazis'],
#  ['polish',
#   'jewish',
#   'musician',
#   'struggles',
#   'survive',
#   'destruction',
#   'warsaw',
#   'ghetto',
#   'world',
#   'war'],
#  ['wheelchair',
#   'bound',
#   'photographer',
#   'spies',
#   'neighbours',
#   'apartment',
#   'window',
#   'becomes',
#   'convinced',
#   'one',
#   'committed',
#   'murder'],
#  ['undercover',
#   'cop',
#   'mole',
#   'police',
#   'attempt',
#   'identify',
#   'infiltrating',
#   'irish',
#   'gang',
#   'south',
#   'boston'],
#  ['promising',
#   'young',
#   'drummer',
#   'enrolls',
#   'cut',
#   'throat',
#   'music',
#   'conservatory',
#   'dreams',
#   'greatness',
#   'mentored',
#   'instructor',
#   'stop',
#   'nothing',
#   'realize',
#   'student',
#   'potential'],
#  ['cyborg',
#   'identical',
#   'one',
#   'failed',
#   'kill',
#   'sarah',
#   'connor',
#   'must',
#   'protect',
#   'ten',
#   'year',
#   'old',
#   'son',
#   'john',
#   'connor',
#   'advanced',
#   'cyborg'],
#  ['marty',
#   'mcfly',
#   'year',
#   'old',
#   'high',
#   'school',
#   'student',
#   'accidentally',
#   'sent',
#   'years',
#   'past',
#   'time',
#   'traveling',
#   'delorean',
#   'invented',
#   'close',
#   'friend',
#   'maverick',
#   'scientist',
#   'doc',
#   'brown'],
#  ['roman',
#   'general',
#   'betrayed',
#   'family',
#   'murdered',
#   'emperor',
#   'corrupt',
#   'son',
#   'comes',
#   'rome',
#   'gladiator',
#   'seek',
#   'revenge'],
#  ['lion',
#   'cub',
#   'future',
#   'king',
#   'simba',
#   'searches',
#   'identity',
#   'eagerness',
#   'please',
#   'others',
#   'penchant',
#   'testing',
#   'boundaries',
#   'sometimes',
#   'gets',
#   'trouble'],
#  ['two',
#   'stage',
#   'magicians',
#   'engage',
#   'competitive',
#   'one',
#   'upmanship',
#   'attempt',
#   'create',
#   'ultimate',
#   'stage',
#   'illusion'],
#  ['vietnam',
#   'war',
#   'captain',
#   'willard',
#   'sent',
#   'dangerous',
#   'mission',
#   'cambodia',
#   'assassinate',
#   'renegade',
#   'colonel',
#   'set',
#   'god',
#   'among',
#   'local',
#   'tribe'],
#  ['man',
#   'juggles',
#   'searching',
#   'wife',
#   'murderer',
#   'keeping',
#   'short',
#   'term',
#   'memory',
#   'loss',
#   'obstacle'],
#  ['dictator',
#   'adenoid',
#   'hynkel',
#   'tries',
#   'expand',
#   'empire',
#   'poor',
#   'jewish',
#   'barber',
#   'tries',
#   'avoid',
#   'persecution',
#   'hynkel',
#   'regime'],
#  ['screenwriter',
#   'hired',
#   'rework',
#   'faded',
#   'silent',
#   'film',
#   'star',
#   'script',
#   'find',
#   'developing',
#   'dangerous',
#   'relationship'],
#  ['space',
#   'merchant',
#   'vessel',
#   'perceives',
#   'unknown',
#   'transmission',
#   'distress',
#   'call',
#   'landing',
#   'source',
#   'moon',
#   'finds',
#   'one',
#   'crew',
#   'attacked',
#   'mysterious',
#   'life',
#   'form',
#   'soon',
#   'realize',
#   'life',
#   'cycle',
#   'merely',
#   'begun'],
#  ['insane',
#   'general',
#   'triggers',
#   'path',
#   'nuclear',
#   'holocaust',
#   'war',
#   'room',
#   'full',
#   'politicians',
#   'generals',
#   'frantically',
#   'try',
#   'stop'],
#  ['refusing',
#   'attack',
#   'enemy',
#   'position',
#   'general',
#   'accuses',
#   'soldiers',
#   'cowardice',
#   'commanding',
#   'officer',
#   'must',
#   'defend'],
#  ['help',
#   'german',
#   'bounty',
#   'hunter',
#   'freed',
#   'slave',
#   'sets',
#   'rescue',
#   'wife',
#   'brutal',
#   'mississippi',
#   'plantation',
#   'owner'],
#  ['family',
#   'heads',
#   'isolated',
#   'hotel',
#   'winter',
#   'evil',
#   'spiritual',
#   'presence',
#   'influences',
#   'father',
#   'violence',
#   'psychic',
#   'son',
#   'sees',
#   'horrific',
#   'forebodings',
#   'past',
#   'future'],
#  ['veteran',
#   'british',
#   'barrister',
#   'must',
#   'defend',
#   'client',
#   'murder',
#   'trial',
#   'surprise',
#   'surprise'],
#  ['eight',
#   'years',
#   'joker',
#   'reign',
#   'anarchy',
#   'dark',
#   'knight',
#   'help',
#   'enigmatic',
#   'selina',
#   'forced',
#   'imposed',
#   'exile',
#   'save',
#   'gotham',
#   'city',
#   'edge',
#   'total',
#   'annihilation',
#   'brutal',
#   'guerrilla',
#   'terrorist',
#   'bane'],
#  ['distant',
#   'future',
#   'small',
#   'waste',
#   'collecting',
#   'robot',
#   'inadvertently',
#   'embarks',
#   'space',
#   'journey',
#   'ultimately',
#   'decide',
#   'fate',
#   'mankind'],
#  ['sexually',
#   'frustrated',
#   'suburban',
#   'father',
#   'mid',
#   'life',
#   'crisis',
#   'becoming',
#   'infatuated',
#   'daughter',
#   'best',
#   'friend'],
#  ['former',
#   'prohibition',
#   'era',
#   'jewish',
#   'gangster',
#   'returns',
#   'lower',
#   'east',
#   'side',
#   'manhattan',
#   'thirty',
#   'years',
#   'later',
#   'must',
#   'confront',
#   'ghosts',
#   'regrets',
#   'old',
#   'life'],
#  ['moon',
#   'alien',
#   'colonized',
#   'contact',
#   'lost',
#   'time',
#   'rescue',
#   'team',
#   'impressive',
#   'firepower',
#   'enough'],
#  ['following',
#   'death',
#   'publishing',
#   'tycoon',
#   'news',
#   'reporters',
#   'scramble',
#   'discover',
#   'meaning',
#   'final',
#   'utterance'],
#  ['hapless',
#   'new',
#   'york',
#   'advertising',
#   'executive',
#   'mistaken',
#   'government',
#   'agent',
#   'group',
#   'foreign',
#   'spies',
#   'pursued',
#   'across',
#   'country',
#   'looks',
#   'way',
#   'survive'],
#  ['san',
#   'francisco',
#   'detective',
#   'suffering',
#   'acrophobia',
#   'investigates',
#   'strange',
#   'activities',
#   'old',
#   'friend',
#   'wife',
#   'becoming',
#   'dangerously',
#   'obsessed'],
#  ['daring',
#   'mission',
#   'rescue',
#   'han',
#   'solo',
#   'jabba',
#   'hutt',
#   'rebels',
#   'dispatch',
#   'endor',
#   'destroy',
#   'powerful',
#   'death',
#   'star',
#   'meanwhile',
#   'luke',
#   'struggles',
#   'help',
#   'vader',
#   'back',
#   'dark',
#   'side',
#   'without',
#   'falling',
#   'emperor',
#   'trap'],
#  ['secret',
#   'bride',
#   'executed',
#   'assaulting',
#   'english',
#   'soldier',
#   'tried',
#   'rape',
#   'sir',
#   'william',
#   'wallace',
#   'begins',
#   'revolt',
#   'king',
#   'edward',
#   'england'],
#  ['simple',
#   'jewelry',
#   'heist',
#   'goes',
#   'terribly',
#   'wrong',
#   'surviving',
#   'criminals',
#   'begin',
#   'suspect',
#   'one',
#   'police',
#   'informant'],
#  ['insurance',
#   'representative',
#   'lets',
#   'talked',
#   'murder',
#   'insurance',
#   'fraud',
#   'scheme',
#   'arouses',
#   'insurance',
#   'investigator',
#   'suspicions'],
#  ['drug',
#   'induced',
#   'utopias',
#   'four',
#   'coney',
#   'island',
#   'people',
#   'shattered',
#   'addictions',
#   'run',
#   'deep'],
#  ['story',
#   'lawrence',
#   'english',
#   'officer',
#   'successfully',
#   'united',
#   'led',
#   'diverse',
#   'often',
#   'warring',
#   'arab',
#   'tribes',
#   'world',
#   'war',
#   'order',
#   'fight',
#   'turks'],
#  ['tramp',
#   'cares',
#   'abandoned',
#   'child',
#   'events',
#   'put',
#   'relationship',
#   'jeopardy'],
#  ['future',
#   'britain',
#   'alex',
#   'delarge',
#   'charismatic',
#   'psycopath',
#   'delinquent',
#   'likes',
#   'practice',
#   'crimes',
#   'ultra',
#   'violence',
#   'gang',
#   'jailed',
#   'volunteers',
#   'experimental',
#   'aversion',
#   'therapy',
#   'developed',
#   'government',
#   'effort',
#   'solve',
#   'society',
#   'crime',
#   'problem',
#   'goes',
#   'according',
#   'plan'],
#  ['incredible',
#   'story',
#   'wolfgang',
#   'amadeus',
#   'mozart',
#   'told',
#   'peer',
#   'secret',
#   'rival',
#   'antonio',
#   'salieri',
#   'confined',
#   'insane',
#   'asylum'],
#  ['atticus',
#   'finch',
#   'lawyer',
#   'depression',
#   'era',
#   'south',
#   'defends',
#   'black',
#   'man',
#   'undeserved',
#   'rape',
#   'charge',
#   'children',
#   'prejudice'],
#  ['relationship',
#   'turns',
#   'sour',
#   'couple',
#   'undergoes',
#   'procedure',
#   'erased',
#   'memories',
#   'process',
#   'loss',
#   'discover',
#   'begin'],
#  ['silent',
#   'film',
#   'production',
#   'company',
#   'cast',
#   'make',
#   'difficult',
#   'transition',
#   'sound'],
#  ['mentally',
#   'unstable',
#   'vietnam',
#   'war',
#   'veteran',
#   'works',
#   'night',
#   'time',
#   'taxi',
#   'driver',
#   'new',
#   'york',
#   'city',
#   'perceived',
#   'decadence',
#   'sleaze',
#   'feeds',
#   'urge',
#   'violent',
#   'action',
#   'attempting',
#   'save',
#   'preadolescent',
#   'prostitute',
#   'process'],
#  ['chicago',
#   'september',
#   'young',
#   'con',
#   'man',
#   'seeking',
#   'revenge',
#   'murdered',
#   'partner',
#   'teams',
#   'master',
#   'big',
#   'con',
#   'win',
#   'fortune',
#   'criminal',
#   'banker'],
#  ['toys',
#   'mistakenly',
#   'delivered',
#   'day',
#   'care',
#   'center',
#   'instead',
#   'attic',
#   'right',
#   'andy',
#   'leaves',
#   'college',
#   'woody',
#   'convince',
#   'toys',
#   'abandoned',
#   'return',
#   'home'],
#  ['humanity',
#   'finds',
#   'mysterious',
#   'obviously',
#   'artificial',
#   'object',
#   'buried',
#   'beneath',
#   'lunar',
#   'surface',
#   'intelligent',
#   'computer',
#   'sets',
#   'quest'],
#  ['pragmatic',
#   'marine',
#   'observes',
#   'dehumanizing',
#   'effects',
#   'vietnam',
#   'war',
#   'fellow',
#   'recruits',
#   'brutal',
#   'boot',
#   'camp',
#   'training',
#   'bloody',
#   'street',
#   'fighting',
#   'hue'],
#  ['coerced',
#   'working',
#   'crime',
#   'boss',
#   'young',
#   'getaway',
#   'driver',
#   'finds',
#   'taking',
#   'part',
#   'heist',
#   'doomed',
#   'fail'],
#  ['cowboy',
#   'doll',
#   'profoundly',
#   'threatened',
#   'jealous',
#   'new',
#   'spaceman',
#   'figure',
#   'supplants',
#   'top',
#   'toy',
#   'boy',
#   'room'],
#  ['nazi',
#   'occupied',
#   'france',
#   'world',
#   'war',
#   'plan',
#   'assassinate',
#   'nazi',
#   'leaders',
#   'group',
#   'jewish',
#   'soldiers',
#   'coincides',
#   'theatre',
#   'owner',
#   'vengeful',
#   'plans'],
#  ['unscrupulous',
#   'boxing',
#   'promoters',
#   'violent',
#   'bookmakers',
#   'russian',
#   'gangster',
#   'incompetent',
#   'amateur',
#   'robbers',
#   'supposedly',
#   'jewish',
#   'jewelers',
#   'fight',
#   'track',
#   'priceless',
#   'stolen',
#   'diamond'],
#  ['man',
#   'tries',
#   'rise',
#   'company',
#   'letting',
#   'executives',
#   'use',
#   'apartment',
#   'trysts',
#   'complications',
#   'romance',
#   'ensue'],
#  ['ingenue',
#   'insinuates',
#   'company',
#   'established',
#   'aging',
#   'stage',
#   'actress',
#   'circle',
#   'theater',
#   'friends'],
#  ['king',
#   'arthur',
#   'knights',
#   'embark',
#   'low',
#   'budget',
#   'search',
#   'grail',
#   'encountering',
#   'many',
#   'silly',
#   'obstacles'],
#  ['miami',
#   'determined',
#   'cuban',
#   'immigrant',
#   'takes',
#   'drug',
#   'cartel',
#   'succumbs',
#   'greed'],
#  ['corruption',
#   'grows',
#   'three',
#   'policemen',
#   'one',
#   'strait',
#   'laced',
#   'one',
#   'brutal',
#   'one',
#   'sleazy',
#   'investigate',
#   'series',
#   'murders',
#   'brand',
#   'justice'],
#  ['hunting',
#   'janitor',
#   'gift',
#   'mathematics',
#   'needs',
#   'help',
#   'psychologist',
#   'find',
#   'direction',
#   'life'],
#  ['fred',
#   'dobbs',
#   'bob',
#   'curtin',
#   'two',
#   'americans',
#   'searching',
#   'work',
#   'mexico',
#   'convince',
#   'old',
#   'prospector',
#   'help',
#   'mine',
#   'gold',
#   'sierra',
#   'madre',
#   'mountains'],
#  ['henry',
#   'jones',
#   'suddenly',
#   'goes',
#   'missing',
#   'pursuing',
#   'holy',
#   'grail',
#   'eminent',
#   'archaeologist',
#   'indiana',
#   'jones',
#   'must',
#   'follow',
#   'father',
#   'footsteps',
#   'stop',
#   'nazis',
#   'getting',
#   'hands',
#   'holy',
#   'grail',
#   'first'],
#  ['two',
#   'male',
#   'musicians',
#   'witness',
#   'mob',
#   'hit',
#   'flee',
#   'state',
#   'female',
#   'band',
#   'disguised',
#   'women',
#   'complications',
#   'set'],
#  ['training',
#   'mentor',
#   'batman',
#   'begins',
#   'fight',
#   'free',
#   'crime',
#   'ridden',
#   'gotham',
#   'city',
#   'corruption',
#   'scarecrow',
#   'league',
#   'shadows',
#   'cast',
#   'upon'],
#  ['seventy',
#   'eight',
#   'year',
#   'old',
#   'carl',
#   'fredricksen',
#   'travels',
#   'paradise',
#   'falls',
#   'home',
#   'equipped',
#   'balloons',
#   'inadvertently',
#   'taking',
#   'young',
#   'stowaway'],
#  ['pulp',
#   'novelist',
#   'holly',
#   'martins',
#   'travels',
#   'shadowy',
#   'postwar',
#   'vienna',
#   'find',
#   'investigating',
#   'mysterious',
#   'death',
#   'old',
#   'friend',
#   'harry',
#   'lime'],
#  ['retired',
#   'old',
#   'west',
#   'gunslinger',
#   'william',
#   'munny',
#   'reluctantly',
#   'takes',
#   'one',
#   'last',
#   'job',
#   'help',
#   'old',
#   'partner',
#   'young',
#   'man'],
#  ['american',
#   'court',
#   'occupied',
#   'germany',
#   'tries',
#   'four',
#   'nazi',
#   'judges',
#   'war',
#   'crimes'],
#  ['emotionally',
#   'self',
#   'destructive',
#   'boxer',
#   'journey',
#   'life',
#   'violence',
#   'temper',
#   'leads',
#   'top',
#   'ring',
#   'destroys',
#   'life',
#   'outside'],
#  ['allied',
#   'prisoners',
#   'war',
#   'plan',
#   'several',
#   'hundred',
#   'number',
#   'escape',
#   'german',
#   'camp',
#   'world',
#   'war'],
#  ['group',
#   'professional',
#   'bank',
#   'robbers',
#   'start',
#   'feel',
#   'heat',
#   'police',
#   'unknowingly',
#   'leave',
#   'clue',
#   'latest',
#   'heist',
#   'sides',
#   'attempt',
#   'find',
#   'balance',
#   'personal',
#   'lives',
#   'professional',
#   'lives'],
#  ['john',
#   'mcclane',
#   'officer',
#   'nypd',
#   'tries',
#   'save',
#   'wife',
#   'holly',
#   'gennaro',
#   'several',
#   'others',
#   'taken',
#   'hostage',
#   'german',
#   'terrorist',
#   'hans',
#   'gruber',
#   'christmas',
#   'party',
#   'nakatomi',
#   'plaza',
#   'los',
#   'angeles'],
#  ['prospector', 'goes', 'klondike', 'search', 'gold', 'finds'],
#  ['private',
#   'detective',
#   'hired',
#   'expose',
#   'adulterer',
#   'finds',
#   'caught',
#   'web',
#   'deceit',
#   'corruption',
#   'murder'],
#  ['prize',
#   'fighter',
#   'turned',
#   'longshoreman',
#   'struggles',
#   'stand',
#   'corrupt',
#   'union',
#   'bosses'],
#  ['naive',
#   'man',
#   'appointed',
#   'fill',
#   'vacancy',
#   'united',
#   'states',
#   'senate',
#   'plans',
#   'promptly',
#   'collide',
#   'political',
#   'corruption',
#   'back'],
#  ['union',
#   'spies',
#   'steal',
#   'engineer',
#   'beloved',
#   'locomotive',
#   'pursues',
#   'single',
#   'handedly',
#   'straight',
#   'enemy',
#   'lines'],
#  ['young',
#   'riley',
#   'uprooted',
#   'midwest',
#   'life',
#   'moved',
#   'san',
#   'francisco',
#   'emotions',
#   'joy',
#   'fear',
#   'anger',
#   'disgust',
#   'sadness',
#   'conflict',
#   'best',
#   'navigate',
#   'new',
#   'city',
#   'house',
#   'school'],
#  ['settling',
#   'differences',
#   'japanese',
#   'pow',
#   'camp',
#   'commander',
#   'british',
#   'colonel',
#   'operates',
#   'oversee',
#   'men',
#   'construction',
#   'railway',
#   'bridge',
#   'captors',
#   'oblivious',
#   'plan',
#   'allies',
#   'destroy'],
#  ['young', 'boy', 'raised', 'within', 'confines', 'small', 'shed'],
#  ['jazz', 'pianist', 'falls', 'aspiring', 'actress', 'los', 'angeles'],
#  ['near',
#   'future',
#   'weary',
#   'logan',
#   'cares',
#   'ailing',
#   'professor',
#   'somewhere',
#   'mexican',
#   'border',
#   'however',
#   'logan',
#   'attempts',
#   'hide',
#   'world',
#   'legacy',
#   'upended',
#   'young',
#   'mutant',
#   'arrives',
#   'pursued',
#   'dark',
#   'forces'],
#  ['blade',
#   'runner',
#   'must',
#   'pursue',
#   'try',
#   'terminate',
#   'four',
#   'replicants',
#   'stole',
#   'ship',
#   'space',
#   'returned',
#   'earth',
#   'find',
#   'creator'],
#  ['botched',
#   'card',
#   'game',
#   'london',
#   'triggers',
#   'four',
#   'friends',
#   'thugs',
#   'weed',
#   'growers',
#   'hard',
#   'gangsters',
#   'loan',
#   'sharks',
#   'debt',
#   'collectors',
#   'collide',
#   'series',
#   'unexpected',
#   'events',
#   'sake',
#   'weed',
#   'cash',
#   'two',
#   'antique',
#   'shotguns'],
#  ['greed',
#   'deception',
#   'money',
#   'power',
#   'murder',
#   'occur',
#   'two',
#   'best',
#   'friends',
#   'mafia',
#   'underboss',
#   'casino',
#   'owner',
#   'trophy',
#   'wife',
#   'gambling',
#   'empire'],
#  ['john',
#   'nash',
#   'brilliant',
#   'asocial',
#   'mathematician',
#   'accepts',
#   'secret',
#   'work',
#   'cryptography',
#   'life',
#   'takes',
#   'turn',
#   'nightmarish'],
#  ['victorian',
#   'surgeon',
#   'rescues',
#   'heavily',
#   'disfigured',
#   'man',
#   'mistreated',
#   'scraping',
#   'living',
#   'side',
#   'show',
#   'freak',
#   'behind',
#   'monstrous',
#   'facade',
#   'revealed',
#   'person',
#   'intelligence',
#   'sensitivity'],
#  ['youngest',
#   'son',
#   'alcoholic',
#   'former',
#   'boxer',
#   'returns',
#   'home',
#   'trained',
#   'father',
#   'competition',
#   'mixed',
#   'martial',
#   'arts',
#   'tournament',
#   'path',
#   'puts',
#   'fighter',
#   'collision',
#   'course',
#   'estranged',
#   'older',
#   'brother'],
#  ['future',
#   'british',
#   'tyranny',
#   'shadowy',
#   'freedom',
#   'fighter',
#   'known',
#   'alias',
#   'plots',
#   'overthrow',
#   'help',
#   'young',
#   'woman'],
#  ['based',
#   'true',
#   'story',
#   'jordan',
#   'belfort',
#   'rise',
#   'wealthy',
#   'stock',
#   'broker',
#   'living',
#   'high',
#   'life',
#   'fall',
#   'involving',
#   'crime',
#   'corruption',
#   'federal',
#   'government'],
#  ['tennis',
#   'pro',
#   'carries',
#   'plot',
#   'murder',
#   'wife',
#   'things',
#   'wrong',
#   'improvises',
#   'brilliant',
#   'plan'],
#  ['wwii',
#   'american',
#   'army',
#   'medic',
#   'desmond',
#   'doss',
#   'served',
#   'battle',
#   'okinawa',
#   'refuses',
#   'kill',
#   'people',
#   'becomes',
#   'first',
#   'man',
#   'american',
#   'history',
#   'receive',
#   'medal',
#   'honor',
#   'without',
#   'firing',
#   'shot'],
#  ['manipulative',
#   'woman',
#   'roguish',
#   'man',
#   'conduct',
#   'turbulent',
#   'romance',
#   'american',
#   'civil',
#   'war',
#   'reconstruction',
#   'periods'],
#  ['century',
#   'mohammed',
#   'peace',
#   'upon',
#   'visited',
#   'angel',
#   'gabriel',
#   'urges',
#   'lead',
#   'people',
#   'mecca',
#   'worship',
#   'god',
#   'exiled',
#   'medina',
#   'returning'],
#  ['self',
#   'conscious',
#   'bride',
#   'tormented',
#   'memory',
#   'husband',
#   'dead',
#   'first',
#   'wife'],
#  ['renton',
#   'deeply',
#   'immersed',
#   'edinburgh',
#   'drug',
#   'scene',
#   'tries',
#   'clean',
#   'get',
#   'despite',
#   'allure',
#   'drugs',
#   'influence',
#   'friends'],
#  ['depth',
#   'examination',
#   'ways',
#   'vietnam',
#   'war',
#   'impacts',
#   'disrupts',
#   'lives',
#   'people',
#   'small',
#   'industrial',
#   'town',
#   'pennsylvania'],
#  ['man', 'refuses', 'conform', 'life', 'rural', 'prison'],
#  ['disgruntled',
#   'korean',
#   'war',
#   'veteran',
#   'walt',
#   'kowalski',
#   'sets',
#   'reform',
#   'neighbor',
#   'hmong',
#   'teenager',
#   'tried',
#   'steal',
#   'kowalski',
#   'prized',
#   'possession',
#   'gran',
#   'torino'],
#  ['dude',
#   'lebowski',
#   'mistaken',
#   'millionaire',
#   'lebowski',
#   'seeks',
#   'restitution',
#   'ruined',
#   'rug',
#   'enlists',
#   'bowling',
#   'buddies',
#   'help',
#   'get'],
#  ['research',
#   'facility',
#   'antarctica',
#   'comes',
#   'across',
#   'alien',
#   'force',
#   'become',
#   'anything',
#   'touches',
#   'accuracy',
#   'members',
#   'must',
#   'find',
#   'human',
#   'late'],
#  ['spoiled',
#   'heiress',
#   'running',
#   'away',
#   'family',
#   'helped',
#   'man',
#   'actually',
#   'reporter',
#   'need',
#   'story'],
#  ['jerry',
#   'lundegaard',
#   'inept',
#   'crime',
#   'falls',
#   'apart',
#   'due',
#   'henchmen',
#   'bungling',
#   'persistent',
#   'police',
#   'work',
#   'quite',
#   'pregnant',
#   'marge',
#   'gunderson'],
#  ['boy',
#   'communicates',
#   'spirits',
#   'know',
#   'dead',
#   'seeks',
#   'help',
#   'disheartened',
#   'child',
#   'psychologist'],
#  ['son',
#   'captured',
#   'great',
#   'barrier',
#   'reef',
#   'taken',
#   'sydney',
#   'timid',
#   'clownfish',
#   'sets',
#   'journey',
#   'bring',
#   'home'],
#  ['tale',
#   'friendship',
#   'two',
#   'unlikely',
#   'pen',
#   'pals',
#   'mary',
#   'lonely',
#   'eight',
#   'year',
#   'old',
#   'girl',
#   'living',
#   'suburbs',
#   'melbourne',
#   'max',
#   'forty',
#   'four',
#   'year',
#   'old',
#   'severely',
#   'obese',
#   'man',
#   'living',
#   'new',
#   'york'],
#  ['violence',
#   'mayhem',
#   'ensue',
#   'hunter',
#   'stumbles',
#   'upon',
#   'drug',
#   'deal',
#   'gone',
#   'wrong',
#   'two',
#   'million',
#   'dollars',
#   'cash',
#   'near',
#   'rio',
#   'grande'],
#  ['hapless',
#   'young',
#   'viking',
#   'aspires',
#   'hunt',
#   'dragons',
#   'becomes',
#   'unlikely',
#   'friend',
#   'young',
#   'dragon',
#   'learns',
#   'may',
#   'creatures',
#   'assumed'],
#  ['story',
#   'family',
#   'religion',
#   'hatred',
#   'oil',
#   'madness',
#   'focusing',
#   'turn',
#   'century',
#   'prospector',
#   'early',
#   'days',
#   'business'],
#  ['graduating',
#   'emory',
#   'university',
#   'top',
#   'student',
#   'athlete',
#   'christopher',
#   'mccandless',
#   'abandons',
#   'possessions',
#   'gives',
#   'entire',
#   'savings',
#   'account',
#   'charity',
#   'hitchhikes',
#   'alaska',
#   'live',
#   'wilderness',
#   'along',
#   'way',
#   'christopher',
#   'encounters',
#   'series',
#   'characters',
#   'shape',
#   'life'],
#  ['bride',
#   'wakens',
#   'four',
#   'year',
#   'coma',
#   'child',
#   'carried',
#   'womb',
#   'gone',
#   'must',
#   'wreak',
#   'vengeance',
#   'team',
#   'assassins',
#   'betrayed',
#   'team',
#   'part'],
#  ['wife',
#   'disappearance',
#   'become',
#   'focus',
#   'intense',
#   'media',
#   'circus',
#   'man',
#   'sees',
#   'spotlight',
#   'turned',
#   'suspected',
#   'may',
#   'innocent'],
#  ['brian',
#   'born',
#   'original',
#   'christmas',
#   'stable',
#   'next',
#   'door',
#   'spends',
#   'life',
#   'mistaken',
#   'messiah'],
#  ['television',
#   'network',
#   'cynically',
#   'exploits',
#   'deranged',
#   'former',
#   'anchor',
#   'ravings',
#   'revelations',
#   'news',
#   'media',
#   'profit'],
#  ['marshal',
#   'investigates',
#   'disappearance',
#   'murderess',
#   'escaped',
#   'hospital',
#   'criminally',
#   'insane'],
#  ['man',
#   'coerced',
#   'confession',
#   'ira',
#   'bombing',
#   'commit',
#   'results',
#   'imprisonment',
#   'father',
#   'well',
#   'english',
#   'lawyer',
#   'fights',
#   'free'],
#  ['merciless',
#   'rivalry',
#   'formula',
#   'one',
#   'rivals',
#   'james',
#   'hunt',
#   'niki',
#   'lauda'],
#  ['paul',
#   'rusesabagina',
#   'hotel',
#   'manager',
#   'housed',
#   'thousand',
#   'tutsi',
#   'refugees',
#   'struggle',
#   'hutu',
#   'militia',
#   'rwanda'],
#  ['young',
#   'recruit',
#   'vietnam',
#   'faces',
#   'moral',
#   'crisis',
#   'confronted',
#   'horrors',
#   'war',
#   'duality',
#   'man'],
#  ['ben',
#   'young',
#   'irish',
#   'boy',
#   'little',
#   'sister',
#   'saoirse',
#   'girl',
#   'turn',
#   'seal',
#   'adventure',
#   'free',
#   'fairies',
#   'save',
#   'spirit',
#   'world'],
#  ['jewish',
#   'prince',
#   'betrayed',
#   'sent',
#   'slavery',
#   'roman',
#   'friend',
#   'regains',
#   'freedom',
#   'comes',
#   'back',
#   'revenge'],
#  ['death',
#   'friend',
#   'writer',
#   'recounts',
#   'boyhood',
#   'journey',
#   'find',
#   'body',
#   'missing',
#   'boy'],
#  ['college', 'professor', 'bond', 'abandoned', 'dog', 'takes', 'home'],
#  ['distant',
#   'poor',
#   'relative',
#   'duke',
#   'ascoyne',
#   'plots',
#   'inherit',
#   'title',
#   'murdering',
#   'eight',
#   'heirs',
#   'stand',
#   'ahead',
#   'line',
#   'succession'],
#  ['private',
#   'detective',
#   'takes',
#   'case',
#   'involves',
#   'three',
#   'eccentric',
#   'criminals',
#   'gorgeous',
#   'liar',
#   'quest',
#   'priceless',
#   'statuette'],
#  ['two',
#   'western',
#   'bank',
#   'train',
#   'robbers',
#   'flee',
#   'bolivia',
#   'law',
#   'gets',
#   'close'],
#  ['baby',
#   'boy',
#   'discovered',
#   'ocean',
#   'liner',
#   'grows',
#   'musical',
#   'prodigy',
#   'never',
#   'setting',
#   'foot',
#   'land'],
#  ['true',
#   'story',
#   'boston',
#   'globe',
#   'uncovered',
#   'massive',
#   'scandal',
#   'child',
#   'molestation',
#   'cover',
#   'within',
#   'local',
#   'catholic',
#   'archdiocese',
#   'shaking',
#   'entire',
#   'catholic',
#   'church',
#   'core'],
#  ['meeting',
#   'stranger',
#   'railway',
#   'station',
#   'woman',
#   'tempted',
#   'cheat',
#   'husband'],
#  ['three',
#   'world',
#   'war',
#   'veterans',
#   'return',
#   'home',
#   'small',
#   'town',
#   'america',
#   'discover',
#   'families',
#   'irreparably',
#   'changed'],
#  ['poor',
#   'midwest',
#   'family',
#   'forced',
#   'land',
#   'travel',
#   'california',
#   'suffering',
#   'misfortunes',
#   'homeless',
#   'great',
#   'depression'],
#  ['antebellum',
#   'united',
#   'states',
#   'solomon',
#   'northup',
#   'free',
#   'black',
#   'man',
#   'upstate',
#   'new',
#   'york',
#   'abducted',
#   'sold',
#   'slavery'],
#  ['adventures',
#   'gustave',
#   'legendary',
#   'concierge',
#   'famous',
#   'hotel',
#   'fictional',
#   'republic',
#   'zubrowka',
#   'first',
#   'second',
#   'world',
#   'wars',
#   'zero',
#   'moustafa',
#   'lobby',
#   'boy',
#   'becomes',
#   'trusted',
#   'friend'],
#  ['woman',
#   'rebels',
#   'tyrannical',
#   'ruler',
#   'postapocalyptic',
#   'australia',
#   'search',
#   'home',
#   'land',
#   'help',
#   'group',
#   'female',
#   'prisoners',
#   'psychotic',
#   'worshipper',
#   'drifter',
#   'named',
#   'max'],
#  ['home',
#   'sick',
#   'bed',
#   'young',
#   'boy',
#   'grandfather',
#   'reads',
#   'story',
#   'called',
#   'princess',
#   'bride'],
#  ['former',
#   'child',
#   'star',
#   'torments',
#   'paraplegic',
#   'sister',
#   'decaying',
#   'hollywood',
#   'mansion'],
#  ['determined',
#   'woman',
#   'works',
#   'hardened',
#   'boxing',
#   'trainer',
#   'become',
#   'professional'],
#  ['preview',
#   'tour',
#   'theme',
#   'park',
#   'suffers',
#   'major',
#   'power',
#   'breakdown',
#   'allows',
#   'cloned',
#   'dinosaur',
#   'exhibits',
#   'run',
#   'amok'],
#  ['stark',
#   'perverse',
#   'story',
#   'murder',
#   'kidnapping',
#   'police',
#   'corruption',
#   'mexican',
#   'border',
#   'town'],
#  ['peter',
#   'parker',
#   'help',
#   'mentor',
#   'tony',
#   'stark',
#   'tries',
#   'balance',
#   'life',
#   'ordinary',
#   'high',
#   'school',
#   'student',
#   'new',
#   'york',
#   'city',
#   'fighting',
#   'crime',
#   'superhero',
#   'alter',
#   'ego',
#   'spider',
#   'man',
#   'new',
#   'threat',
#   'emerges'],
#  ['young',
#   'man',
#   'woman',
#   'meet',
#   'train',
#   'europe',
#   'wind',
#   'spending',
#   'one',
#   'evening',
#   'together',
#   'vienna',
#   'unfortunately',
#   'know',
#   'probably',
#   'night',
#   'together'],
#  ['insurance',
#   'salesman',
#   'adjuster',
#   'discovers',
#   'entire',
#   'life',
#   'actually',
#   'television',
#   'show'],
#  ['harry',
#   'ron',
#   'hermione',
#   'search',
#   'voldemort',
#   'remaining',
#   'horcruxes',
#   'effort',
#   'destroy',
#   'dark',
#   'lord',
#   'final',
#   'battle',
#   'rages',
#   'hogwarts'],
#  ['three',
#   'decades',
#   'empire',
#   'defeat',
#   'new',
#   'threat',
#   'arises',
#   'militant',
#   'first',
#   'order',
#   'stormtrooper',
#   'defector',
#   'finn',
#   'spare',
#   'parts',
#   'scavenger',
#   'rey',
#   'caught',
#   'resistance',
#   'search',
#   'missing',
#   'luke',
#   'skywalker'],
#  ['travis',
#   'henderson',
#   'aimless',
#   'drifter',
#   'missing',
#   'four',
#   'years',
#   'wanders',
#   'desert',
#   'must',
#   'reconnect',
#   'society',
#   'life',
#   'family'],
#  ['group',
#   'high',
#   'schoolers',
#   'come',
#   'age',
#   'bleak',
#   'isolated',
#   'atrophied',
#   'west',
#   'texas',
#   'town',
#   'slowly',
#   'dying',
#   'culturally',
#   'economically'],
#  ['gandhi',
#   'character',
#   'fully',
#   'explained',
#   'man',
#   'nonviolence',
#   'patience',
#   'able',
#   'drive',
#   'british',
#   'subcontinent',
#   'stubborn',
#   'nature',
#   'jinnah',
#   'commitment',
#   'towards',
#   'pakistan',
#   'portrayed'],
#  ['irish',
#   'rogue',
#   'wins',
#   'heart',
#   'rich',
#   'widow',
#   'assumes',
#   'dead',
#   'husband',
#   'aristocratic',
#   'position',
#   'century',
#   'england'],
#  ['rocky',
#   'balboa',
#   'small',
#   'time',
#   'boxer',
#   'gets',
#   'supremely',
#   'rare',
#   'chance',
#   'fight',
#   'heavy',
#   'weight',
#   'champion',
#   'apollo',
#   'creed',
#   'bout',
#   'strives',
#   'distance',
#   'self',
#   'respect'],
#  ['neurotic',
#   'new',
#   'york',
#   'comedian',
#   'alvy',
#   'singer',
#   'falls',
#   'love',
#   'ditzy',
#   'annie',
#   'hall'],
#  ['keller',
#   'dover',
#   'daughter',
#   'friend',
#   'missing',
#   'takes',
#   'matters',
#   'hands',
#   'police',
#   'pursue',
#   'multiple',
#   'leads',
#   'pressure',
#   'mounts'],
#  ['troubled',
#   'teenager',
#   'plagued',
#   'visions',
#   'man',
#   'large',
#   'rabbit',
#   'suit',
#   'manipulates',
#   'commit',
#   'series',
#   'crimes',
#   'narrowly',
#   'escapes',
#   'bizarre',
#   'accident'],
#  ['story',
#   'frank',
#   'abagnale',
#   'birthday',
#   'successfully',
#   'forged',
#   'millions',
#   'dollars',
#   'worth',
#   'checks',
#   'posing',
#   'pan',
#   'pilot',
#   'doctor',
#   'legal',
#   'prosecutor',
#   'seasoned',
#   'dedicated',
#   'fbi',
#   'agent',
#   'pursues'],
#  ['senator',
#   'became',
#   'famous',
#   'killing',
#   'notorious',
#   'outlaw',
#   'returns',
#   'funeral',
#   'old',
#   'friend',
#   'tells',
#   'truth',
#   'deed'],
#  ['police',
#   'detective',
#   'falls',
#   'love',
#   'woman',
#   'whose',
#   'murder',
#   'investigating'],
#  ['order',
#   'power',
#   'city',
#   'monsters',
#   'scare',
#   'children',
#   'scream',
#   'however',
#   'children',
#   'toxic',
#   'monsters',
#   'child',
#   'gets',
#   'monsters',
#   'realize',
#   'things',
#   'may',
#   'think'],
#  ['jason',
#   'bourne',
#   'dodges',
#   'ruthless',
#   'cia',
#   'official',
#   'agents',
#   'new',
#   'assassination',
#   'program',
#   'searching',
#   'origins',
#   'life',
#   'trained',
#   'killer'],
#  ['brick',
#   'alcoholic',
#   'football',
#   'player',
#   'drinks',
#   'days',
#   'away',
#   'resists',
#   'affections',
#   'wife',
#   'maggie',
#   'reunion',
#   'father',
#   'big',
#   'daddy',
#   'dying',
#   'cancer',
#   'jogs',
#   'host',
#   'memories',
#   'revelations',
#   'father',
#   'son'],
#  ['dorothy',
#   'gale',
#   'swept',
#   'away',
#   'farm',
#   'kansas',
#   'magical',
#   'land',
#   'tornado',
#   'embarks',
#   'quest',
#   'new',
#   'friends',
#   'see',
#   'wizard',
#   'help',
#   'return',
#   'home',
#   'kansas',
#   'help',
#   'friends',
#   'well'],
#  ['man',
#   'loves',
#   'games',
#   'theater',
#   'invites',
#   'wife',
#   'lover',
#   'meet',
#   'setting',
#   'battle',
#   'wits',
#   'potentially',
#   'deadly',
#   'results'],
#  ['bored',
#   'sheltered',
#   'princess',
#   'escapes',
#   'guardians',
#   'falls',
#   'love',
#   'american',
#   'newsman',
#   'rome'],
#  ['private',
#   'eye',
#   'escapes',
#   'past',
#   'run',
#   'gas',
#   'station',
#   'small',
#   'town',
#   'past',
#   'catches',
#   'must',
#   'return',
#   'big',
#   'city',
#   'world',
#   'danger',
#   'corruption',
#   'double',
#   'crosses',
#   'duplicitous',
#   'dames'],
#  ['murder',
#   'trial',
#   'defendant',
#   'says',
#   'suffered',
#   'temporary',
#   'insanity',
#   'victim',
#   'raped',
#   'wife',
#   'truth',
#   'win',
#   'case'],
#  ['bitter',
#   'aging',
#   'couple',
#   'help',
#   'alcohol',
#   'use',
#   'young',
#   'couple',
#   'fuel',
#   'anguish',
#   'emotional',
#   'pain',
#   'towards'],
#  ['seemingly',
#   'indestructible',
#   'humanoid',
#   'cyborg',
#   'sent',
#   'assassinate',
#   'waitress',
#   'whose',
#   'unborn',
#   'son',
#   'lead',
#   'humanity',
#   'war',
#   'machines',
#   'soldier',
#   'war',
#   'sent',
#   'protect',
#   'costs'],
#  ['weatherman', 'finds', 'inexplicably', 'living', 'day'],
#  ['aspiring',
#   'author',
#   'civil',
#   'rights',
#   'movement',
#   'decides',
#   'write',
#   'book',
#   'detailing',
#   'african',
#   'american',
#   'maids',
#   'point',
#   'view',
#   'white',
#   'families',
#   'work',
#   'hardships',
#   'daily',
#   'basis'],
#  ['psychotic',
#   'socialite',
#   'confronts',
#   'pro',
#   'tennis',
#   'star',
#   'theory',
#   'two',
#   'complete',
#   'strangers',
#   'get',
#   'away',
#   'murder',
#   'theory',
#   'plans',
#   'implement'],
#  ['religious',
#   'fanatic',
#   'marries',
#   'gullible',
#   'widow',
#   'whose',
#   'young',
#   'children',
#   'reluctant',
#   'tell',
#   'real',
#   'daddy',
#   'hid',
#   'stolen',
#   'robbery'],
#  ['young',
#   'soldier',
#   'faces',
#   'profound',
#   'disillusionment',
#   'soul',
#   'destroying',
#   'horror',
#   'world',
#   'war'],
#  ['young',
#   'woman',
#   'whose',
#   'father',
#   'imprisoned',
#   'terrifying',
#   'beast',
#   'offers',
#   'place',
#   'unaware',
#   'captor',
#   'actually',
#   'prince',
#   'physically',
#   'altered',
#   'magic',
#   'spell'],
#  ['five',
#   'year',
#   'old',
#   'indian',
#   'boy',
#   'gets',
#   'lost',
#   'streets',
#   'calcutta',
#   'thousands',
#   'kilometers',
#   'home',
#   'survives',
#   'many',
#   'challenges',
#   'adopted',
#   'couple',
#   'australia',
#   'years',
#   'later',
#   'sets',
#   'find',
#   'lost',
#   'family'],
#  ['future',
#   'world',
#   'devastated',
#   'disease',
#   'convict',
#   'sent',
#   'back',
#   'time',
#   'gather',
#   'information',
#   'man',
#   'made',
#   'virus',
#   'wiped',
#   'human',
#   'population',
#   'planet'],
#  ['group',
#   'intergalactic',
#   'criminals',
#   'forced',
#   'work',
#   'together',
#   'stop',
#   'fanatical',
#   'warrior',
#   'taking',
#   'control',
#   'universe'],
#  ['man',
#   'robs',
#   'bank',
#   'pay',
#   'lover',
#   'operation',
#   'turns',
#   'hostage',
#   'situation',
#   'media',
#   'circus'],
#  ['giant',
#   'great',
#   'white',
#   'shark',
#   'arrives',
#   'shores',
#   'new',
#   'england',
#   'beach',
#   'resort',
#   'wreaks',
#   'havoc',
#   'bloody',
#   'attacks',
#   'swimmers',
#   'local',
#   'sheriff',
#   'teams',
#   'marine',
#   'biologist',
#   'old',
#   'seafarer',
#   'hunt',
#   'monster'],
#  ['city',
#   'anthropomorphic',
#   'animals',
#   'rookie',
#   'bunny',
#   'cop',
#   'cynical',
#   'con',
#   'artist',
#   'fox',
#   'must',
#   'work',
#   'together',
#   'uncover',
#   'conspiracy'],
#  ['guardians',
#   'must',
#   'fight',
#   'keep',
#   'newfound',
#   'family',
#   'together',
#   'unravel',
#   'mystery',
#   'peter',
#   'quill',
#   'true',
#   'parentage'],
#  ['blacksmith',
#   'turner',
#   'teams',
#   'eccentric',
#   'pirate',
#   'captain',
#   'jack',
#   'sparrow',
#   'save',
#   'love',
#   'governor',
#   'daughter',
#   'jack',
#   'former',
#   'pirate',
#   'allies',
#   'undead'],
#  ['nine',
#   'years',
#   'jesse',
#   'celine',
#   'first',
#   'met',
#   'encounter',
#   'french',
#   'leg',
#   'jesse',
#   'book',
#   'tour'],
#  ['world',
#   'war',
#   'mathematician',
#   'alan',
#   'turing',
#   'tries',
#   'crack',
#   'enigma',
#   'code',
#   'help',
#   'fellow',
#   'mathematicians'],
#  ['american',
#   'grandson',
#   'infamous',
#   'scientist',
#   'struggling',
#   'prove',
#   'insane',
#   'people',
#   'believe',
#   'invited',
#   'transylvania',
#   'discovers',
#   'process',
#   'reanimates',
#   'dead',
#   'body'],
#  ['two',
#   'escaping',
#   'american',
#   'world',
#   'war',
#   'prisoners',
#   'killed',
#   'german',
#   'pow',
#   'camp',
#   'barracks',
#   'black',
#   'marketeer',
#   'sefton',
#   'suspected',
#   'informer'],
#  ['woman',
#   'run',
#   'mob',
#   'reluctantly',
#   'accepted',
#   'small',
#   'colorado',
#   'town',
#   'exchange',
#   'agrees',
#   'work',
#   'search',
#   'visits',
#   'town',
#   'finds',
#   'support',
#   'price',
#   'yet',
#   'dangerous',
#   'secret',
#   'never',
#   'far',
#   'away'],
#  ['english',
#   'teacher',
#   'john',
#   'keating',
#   'inspires',
#   'students',
#   'look',
#   'poetry',
#   'different',
#   'perspective',
#   'authentic',
#   'knowledge',
#   'feelings'],
#  ['marshal',
#   'kane',
#   'personally',
#   'compelled',
#   'face',
#   'returning',
#   'deadly',
#   'enemy',
#   'frank',
#   'miller',
#   'finds',
#   'fellow',
#   'townspeople',
#   'refuse',
#   'help'],
#  ['man',
#   'befriends',
#   'fellow',
#   'criminal',
#   'two',
#   'begin',
#   'serving',
#   'sentence',
#   'dreadful',
#   'prison',
#   'island',
#   'inspires',
#   'man',
#   'plot',
#   'escape'],
#  ['disturbed',
#   'blanche',
#   'dubois',
#   'moves',
#   'sister',
#   'new',
#   'orleans',
#   'tormented',
#   'brutish',
#   'brother',
#   'law',
#   'reality',
#   'crumbles',
#   'around'],
#  ['drama',
#   'critic',
#   'learns',
#   'wedding',
#   'day',
#   'beloved',
#   'maiden',
#   'aunts',
#   'homicidal',
#   'maniacs',
#   'insanity',
#   'runs',
#   'family'],
#  ['film',
#   'explores',
#   'dark',
#   'miserable',
#   'town',
#   'basin',
#   'city',
#   'tells',
#   'story',
#   'three',
#   'different',
#   'people',
#   'caught',
#   'violent',
#   'corruption'],
#  ['coming',
#   'pool',
#   'player',
#   'plays',
#   'long',
#   'time',
#   'champion',
#   'single',
#   'high',
#   'stakes',
#   'match'],
#  ['sly',
#   'business',
#   'manager',
#   'two',
#   'wacky',
#   'friends',
#   'two',
#   'opera',
#   'singers',
#   'help',
#   'achieve',
#   'success',
#   'humiliating',
#   'stuffy',
#   'snobbish',
#   'enemies'],
#  ['crooks', 'plan', 'execute', 'daring', 'race', 'track', 'robbery'],
#  ['earth',
#   'mightiest',
#   'heroes',
#   'must',
#   'come',
#   'together',
#   'learn',
#   'fight',
#   'team',
#   'stop',
#   'mischievous',
#   'loki',
#   'alien',
#   'army',
#   'enslaving',
#   'humanity'],
#  ['woman',
#   'asked',
#   'spy',
#   'group',
#   'nazi',
#   'friends',
#   'south',
#   'america',
#   'far',
#   'ingratiate'],
#  ['due',
#   'insistence',
#   'invisible',
#   'six',
#   'foot',
#   'tall',
#   'rabbit',
#   'best',
#   'friend',
#   'whimsical',
#   'middle',
#   'aged',
#   'man',
#   'thought',
#   'family',
#   'insane',
#   'may',
#   'wiser',
#   'anyone',
#   'knows'],
#  ['astronaut',
#   'becomes',
#   'stranded',
#   'mars',
#   'team',
#   'assume',
#   'dead',
#   'must',
#   'rely',
#   'ingenuity',
#   'find',
#   'way',
#   'signal',
#   'earth',
#   'alive'],
#  ['teenage',
#   'girl',
#   'possessed',
#   'mysterious',
#   'entity',
#   'mother',
#   'seeks',
#   'help',
#   'two',
#   'priests',
#   'save',
#   'daughter'],
#  ['small',
#   'town',
#   'sheriff',
#   'american',
#   'west',
#   'enlists',
#   'help',
#   'cripple',
#   'drunk',
#   'young',
#   'gunfighter',
#   'efforts',
#   'hold',
#   'jail',
#   'brother',
#   'local',
#   'bad',
#   'guy'],
#  ['rich',
#   'woman',
#   'husband',
#   'tabloid',
#   'type',
#   'reporter',
#   'turn',
#   'planned',
#   'remarriage',
#   'begins',
#   'learn',
#   'truth'],
#  ['two',
#   'young',
#   'men',
#   'strangle',
#   'inferior',
#   'classmate',
#   'hide',
#   'body',
#   'apartment',
#   'invite',
#   'friends',
#   'family',
#   'dinner',
#   'party',
#   'means',
#   'challenge',
#   'perfection',
#   'crime'],
#  ['private',
#   'detective',
#   'philip',
#   'marlowe',
#   'hired',
#   'rich',
#   'family',
#   'complex',
#   'case',
#   'seen',
#   'murder',
#   'blackmail',
#   'might',
#   'love'],
#  ['confined',
#   'troubled',
#   'rock',
#   'star',
#   'descends',
#   'madness',
#   'midst',
#   'physical',
#   'social',
#   'isolation',
#   'everyone'],
#  ['story',
#   'king',
#   'george',
#   'united',
#   'kingdom',
#   'great',
#   'britain',
#   'northern',
#   'ireland',
#   'impromptu',
#   'ascension',
#   'throne',
#   'speech',
#   'therapist',
#   'helped',
#   'unsure',
#   'monarch',
#   'become',
#   'worthy'],
#  ['young',
#   'boy',
#   'named',
#   'ralphie',
#   'attempts',
#   'convince',
#   'parents',
#   'teacher',
#   'santa',
#   'red',
#   'ryder',
#   'gun',
#   'really',
#   'perfect',
#   'christmas',
#   'gift'],
#  ['disillusioned',
#   'college',
#   'graduate',
#   'finds',
#   'torn',
#   'older',
#   'lover',
#   'daughter'],
#  ['new',
#   'orleans',
#   'discovers',
#   'kennedy',
#   'assassination',
#   'official',
#   'story'],
#  ['karl',
#   'childers',
#   'simple',
#   'man',
#   'hospitalized',
#   'since',
#   'childhood',
#   'murder',
#   'mother',
#   'lover',
#   'released',
#   'start',
#   'new',
#   'life',
#   'small',
#   'town'],
#  ['fisherman',
#   'smuggler',
#   'syndicate',
#   'businessmen',
#   'match',
#   'wits',
#   'possession',
#   'priceless',
#   'diamond'],
#  ['epic',
#   'mosaic',
#   'interrelated',
#   'characters',
#   'search',
#   'love',
#   'forgiveness',
#   'meaning',
#   'san',
#   'fernando',
#   'valley'],
#  ['selfish',
#   'yuppie',
#   'charlie',
#   'babbitt',
#   'father',
#   'left',
#   'fortune',
#   'savant',
#   'brother',
#   'raymond',
#   'pittance',
#   'charlie',
#   'travel',
#   'cross',
#   'country'],
#  ['frontiersman',
#   'fur',
#   'trading',
#   'expedition',
#   'fights',
#   'survival',
#   'mauled',
#   'bear',
#   'left',
#   'dead',
#   'members',
#   'hunting',
#   'team'],
#  ['jack',
#   'skellington',
#   'king',
#   'halloween',
#   'town',
#   'discovers',
#   'christmas',
#   'town',
#   'attempts',
#   'bring',
#   'christmas',
#   'home',
#   'cause',
#   'confusion'],
#  ['former',
#   'prisoner',
#   'war',
#   'brainwashed',
#   'unwitting',
#   'assassin',
#   'international',
#   'communist',
#   'conspiracy'],
#  ['fast',
#   'talking',
#   'mercenary',
#   'morbid',
#   'sense',
#   'humor',
#   'subjected',
#   'rogue',
#   'experiment',
#   'leaves',
#   'accelerated',
#   'healing',
#   'powers',
#   'quest',
#   'revenge'],
#  ['aging',
#   'group',
#   'outlaws',
#   'look',
#   'one',
#   'last',
#   'big',
#   'score',
#   'traditional',
#   'american',
#   'west',
#   'disappearing',
#   'around'],
#  ['street',
#   'urchin',
#   'vies',
#   'love',
#   'beautiful',
#   'princess',
#   'uses',
#   'genie',
#   'magic',
#   'power',
#   'make',
#   'prince',
#   'order',
#   'marry'],
#  ['frustrated',
#   'son',
#   'tries',
#   'determine',
#   'fact',
#   'fiction',
#   'dying',
#   'father',
#   'life'],
#  ['world',
#   'war',
#   'phase',
#   'career',
#   'controversial',
#   'american',
#   'general',
#   'george',
#   'patton'],
#  ['desperate',
#   'life',
#   'chronic',
#   'alcoholic',
#   'followed',
#   'four',
#   'day',
#   'drinking',
#   'bout'],
#  ['something',
#   'supervising',
#   'staff',
#   'member',
#   'residential',
#   'treatment',
#   'facility',
#   'navigates',
#   'troubled',
#   'waters',
#   'world',
#   'alongside',
#   'worker',
#   'longtime',
#   'boyfriend'],
#  ['newspaper',
#   'editor',
#   'uses',
#   'every',
#   'trick',
#   'book',
#   'keep',
#   'ace',
#   'reporter',
#   'wife',
#   'remarrying'],
#  ['old',
#   'man',
#   'makes',
#   'long',
#   'journey',
#   'lawn',
#   'mover',
#   'tractor',
#   'mend',
#   'relationship',
#   'ill',
#   'brother'],
#  ['mumbai',
#   'teen',
#   'reflects',
#   'upbringing',
#   'slums',
#   'accused',
#   'cheating',
#   'indian',
#   'version',
#   'wants',
#   'millionaire']]

# %%
df['clean_plot'] = plot

# %%
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, number, years, fi...
# 1      [aging, patriarch, organized, crime, dynasty, ...
# 2      [early, life, career, vito, corleone, new, yor...
# 3      [menace, known, joker, emerges, mysterious, pa...
# 4      [jury, holdout, attempts, prevent, miscarriage...
#                              ...
# 245    [desperate, life, chronic, alcoholic, followed...
# 246    [something, supervising, staff, member, reside...
# 247    [newspaper, editor, uses, every, trick, book, ...
# 248    [old, man, makes, long, journey, lawn, mover, ...
# 249    [mumbai, teen, reflects, upbringing, slums, ac...
# Name: clean_plot, Length: 250, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1           2             The Godfather  1972         R  24 Mar 1972  175 min
# 2           3    The Godfather: Part II  1974         R  20 Dec 1974  202 min
# 3           4           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 4           5              12 Angry Men  1957  APPROVED  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3  1,825,626  tt0111161  movie
# 1        9.2/10      100.0         9.2  1,243,444  tt0068646  movie
# 2        9.0/10       85.0         9.0    856,870  tt0071562  movie
# 3        9.0/10       82.0         9.0  1,802,351  tt0468569  movie
# 4        8.9/10       96.0         8.9    494,215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website  Response  \
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True
#
#                                           clean_plot
# 0  [two, imprisoned, men, bond, number, years, fi...
# 1  [aging, patriarch, organized, crime, dynasty, ...
# 2  [early, life, career, vito, corleone, new, yor...
# 3  [menace, known, joker, emerges, mysterious, pa...
# 4  [jury, holdout, attempts, prevent, miscarriage...

# %%
df['Genre'] = df['Genre'].apply(lambda x: x.split(','))
df['Actors'] = df['Actors'].apply(lambda x: x.split(',')[:4])
df['Director'] = df['Director'].apply(lambda x: x.split(','))

# %%
df["Actors"][0]
# Out:
# ['Tim Robbins', ' Morgan Freeman', ' Bob Gunton', ' William Sadler']

# %%
columns = ['clean_plot', 'Genre', 'Actors', 'Director']
l = []
for i in range(len(df)):
    words = ''
    for col in columns:
        words += ' '.join(df[col][i]) + ' '
    l.append(words)
l
# Out:
# ['two imprisoned men bond number years finding solace eventual redemption acts common decency Crime  Drama Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler Frank Darabont ',
#  'aging patriarch organized crime dynasty transfers control clandestine empire reluctant son Crime  Drama Marlon Brando  Al Pacino  James Caan  Richard S. Castellano Francis Ford Coppola ',
#  'early life career vito corleone new york portrayed son michael expands tightens grip family crime syndicate Crime  Drama Al Pacino  Robert Duvall  Diane Keaton  Robert De Niro Francis Ford Coppola ',
#  'menace known joker emerges mysterious past wreaks havoc chaos people gotham dark knight must accept one greatest psychological physical tests ability fight injustice Action  Crime  Drama Christian Bale  Heath Ledger  Aaron Eckhart  Michael Caine Christopher Nolan ',
#  'jury holdout attempts prevent miscarriage justice forcing colleagues reconsider evidence Crime  Drama Martin Balsam  John Fiedler  Lee J. Cobb  E.G. Marshall Sidney Lumet ',
#  'old man makes long journey lawn mover tractor mend relationship ill brother Biography  Drama Sissy Spacek  Jane Galloway Heitz  Joseph A. Carpenter  Donald Wiegert David Lynch ',
#  'mumbai teen reflects upbringing slums accused cheating indian version wants millionaire Drama Dev Patel  Saurabh Shukla  Anil Kapoor  Raj Zutshi Danny Boyle  Loveleen Tandan ']

# %%
df['clean_input'] = l
df = df[['Title', 'clean_input']]
df.head()
# Out:
#                       Title                                        clean_input
# 0  The Shawshank Redemption  two imprisoned men bond number years finding s...
# 1             The Godfather  aging patriarch organized crime dynasty transf...
# 2    The Godfather: Part II  early life career vito corleone new york portr...
# 3           The Dark Knight  menace known joker emerges mysterious past wre...
# 4              12 Angry Men  jury holdout attempts prevent miscarriage just...

# %% [markdown]
# # Feature Extraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf = TfidfVectorizer()
features = tfidf.fit_transform(df['clean_input'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(features, features)
print(cosine_sim)
# Out:
# [[1.         0.02328087 0.02163437 ... 0.00312364 0.00302999 0.00280317]
#  [0.02328087 1.         0.25644103 ... 0.00326917 0.00317115 0.00293377]
#  [0.02163437 0.25644103 1.         ... 0.00303796 0.00294688 0.00272628]
#  ...
#  [0.00312364 0.00326917 0.00303796 ... 1.         0.00308842 0.00285723]
#  [0.00302999 0.00317115 0.00294688 ... 0.00308842 1.         0.00277156]
#  [0.00280317 0.00293377 0.00272628 ... 0.00285723 0.00277156 1.        ]]

# %% [markdown]
# # Movie Recommendation

# %%
index = pd.Series(df['Title'])
index.head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                12 Angry Men
# Name: Title, dtype: object

# %%
def recommend_movies(title):
    movies = []
    idx = index[index == title].index[0]
    # print(idx)
    score = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    top10 = list(score.iloc[1:11].index)
    # print(top10)
    
    for i in top10:
        movies.append(df['Title'][i])
    return movies

# %%
recommend_movies('The Dark Knight Rises')
# Out:
# ['The Dark Knight',
#  'Inception',
#  'Batman Begins',
#  'The Prestige',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Die Hard',
#  'Léon: The Professional',
#  'Mad Max: Fury Road',
#  'Memento',
#  'Sin City']

# %%
index[index == 'The Dark Knight Rises'].index[0]
# Out:
# 51

# %%
pd.Series(cosine_sim[3]).sort_values(ascending=False)
# Out:
# 3      1.000000
# 89     0.227968
# 51     0.212481
# 40     0.172792
# 187    0.076834
#          ...
# 70     0.000000
# 58     0.000000
# 30     0.000000
# 225    0.000000
# 191    0.000000
# Length: 250, dtype: float64

# %%
recommend_movies('The Shawshank Redemption')
# Out:
# ['Pulp Fiction',
#  'Se7en',
#  'Unforgiven',
#  'The Green Mile',
#  'The Treasure of the Sierra Madre',
#  'Million Dollar Baby',
#  'Rope',
#  'Goodfellas',
#  'Sling Blade',
#  'Up']

# %%
recommend_movies('The Avengers')
# Out:
# ['Guardians of the Galaxy Vol. 2',
#  'Guardians of the Galaxy',
#  'Aliens',
#  'Spider-Man: Homecoming',
#  'Rush',
#  'The Martian',
#  'Interstellar',
#  'Blade Runner',
#  'The Thing',
#  'Kill Bill: Vol. 1']

# %%
len(df)
# Out:
# 250
